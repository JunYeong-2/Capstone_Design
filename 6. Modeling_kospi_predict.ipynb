# %% [markdown]
# <a href="https://colab.research.google.com/github/Gayeon6423/BusinessAI-Capston/blob/main/6_Modeling_kospi_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras import optimizers
from tensorflow.keras.layers import LSTM, Dropout, Dense, Conv1D, MaxPooling1D, Flatten
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import Dropout, Flatten,TimeDistributed
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


stock_data = pd.read_csv('/content/drive/MyDrive/산업 AI 캡스톤/DATA/Total_Data/Final_Feature_kospi_sen_all.csv')
stock_data
# Out:
#          Date  Kospi_close  Kospi_high  ko_interest  oil_open  ex_JP_low  \
# 0    20210105      2990.57       0.795          0.0     0.213      0.590
# 1    20210106      2968.21       0.819          0.0     0.219      0.596
# 2    20210107      3031.68       0.839          0.0     0.225      0.597
# 3    20210108      3152.18       0.855          0.0     0.230      0.584
# 4    20210111      3148.45       0.914          0.0     0.232      0.584
# ..        ...          ...         ...          ...       ...        ...
# 583  20230623      2570.10       0.601          1.0     0.651      0.028
# 584  20230626      2582.20       0.602          1.0     0.651      0.024
# 585  20230627      2581.39       0.594          1.0     0.651      0.000
# 586  20230628      2564.19       0.592          1.0     0.651      0.011
# 587  20230629      2550.02       0.597          1.0     0.651      0.020
#
#      gold_low  us500_low  klue_bert_score_summarize_content  oil_vol  \
# 0       0.661      0.581                             -0.536    0.013
# 1       0.650      0.585                              1.381    0.006
# 2       0.670      0.608                              1.845    0.007
# 3       0.631      0.615                              2.497    0.004
# 4       0.623      0.617                             -0.951    0.009
# ..        ...        ...                                ...      ...
# 583     0.212      0.830                              0.402    0.000
# 584     0.212      0.825                             -0.385    0.000
# 585     0.208      0.828                             -0.447    0.000
# 586     0.217      0.838                              0.777    0.000
# 587     0.208      0.842                             -0.038    0.000
#
#      research_kospi  dji_vol  us500_vol  \
# 0             0.413    0.280      0.349
# 1             0.628    0.470      0.527
# 2             0.427    0.378      0.410
# 3             0.512    0.318      0.371
# 4             0.881    0.287      0.334
# ..              ...      ...        ...
# 583           0.125    0.316      0.526
# 584           0.120    0.170      0.207
# 585           0.118    0.206      0.226
# 586           0.128    0.174      0.246
# 587           0.127    0.189      0.241
#
#      kofinbert_score_summarize_content_kospi  kofinbert_score_title_kospi  \
# 0                                      0.157                        0.195
# 1                                      1.236                        0.569
# 2                                      0.537                        1.395
# 3                                      0.697                       -1.382
# 4                                      0.331                       -0.044
# ..                                       ...                          ...
# 583                                    0.834                       -0.339
# 584                                   -0.196                        0.681
# 585                                   -0.208                        0.625
# 586                                    1.099                        0.892
# 587                                    0.382                       -0.145
#
#      klue_bert_score_title
# 0                    0.823
# 1                    0.722
# 2                   -0.675
# 3                    1.124
# 4                    0.730
# ..                     ...
# 583                  0.831
# 584                 -0.001
# 585                 -0.097
# 586                  0.253
# 587                 -0.378
#
# [588 rows x 16 columns]

# %%
# 데이터 전처리
data = stock_data['Kospi_close'].values.reshape(-1, 1)
stock_data = stock_data.drop(['Kospi_close'],axis=1)
stock_data = stock_data.drop(['Date'],axis=1)

# %%
# 데이터 분할
train_size = int(len(data) * 0.85)
train_data, test_data = data[:train_size], data[train_size:]
train_data_t, test_data_t = stock_data[:train_size], stock_data[train_size:]

def create_dataset(dataset, data, look_back=10):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(dataset[i:(i + look_back)])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

look_back = 10  # 몇 일 동안의 데이터를 사용할 것인지 설정

trainX, trainY = create_dataset(train_data_t, train_data, look_back)
testX, testY = create_dataset(test_data_t,test_data, look_back)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (489, 10, 12)
# (489, 1)
# (79, 10, 12)
# (79, 1)

# %%
def accuracy(list1,list2):
  list1 = list1.flatten().tolist()
  list2 = list2.flatten().tolist()
  value_1 = []
  value_2 = []
  j = 0
  if len(list1) == len(list2):
    for i in range(len(list1)-1):
      if list1[i+1] > list1[i]:
        value_1.append(1)
      elif list1[i+1] == list1[i]:
        value_1.append(0)
      else:
        value_1.append(-1)
    for i in range(len(list1)-1):
      if list2[i+1] > list2[i]:
        value_2.append(1)
      elif list2[i+1] == list2[i]:
        value_2.append(0)
      else:
        value_2.append(-1)
    for i in range(len(value_1)):
      if value_1[i] == value_2[i]:
        j = j + 1
    accuracy = j/len(value_1) * 100
    print("accuracy : %d" % accuracy)
  else:
    print("길이가 다릅니다.")

# %%
# 모델 생성 GRU+CNN
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(GRU(units=1024, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()


# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=4000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./ko_sum_CNN_GRU__weights.h2')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# WARNING:tensorflow:Layer gru_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 2751/4000
#
# Epoch 2751: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 278404.8125 - val_loss: 6338.1836 - 718ms/epoch - 103ms/step
# Epoch 2752/4000
#
# Epoch 2752: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 249771.3438 - val_loss: 5821.5942 - 524ms/epoch - 75ms/step
# Epoch 2753/4000
#
# Epoch 2753: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 253075.6562 - val_loss: 5935.3442 - 559ms/epoch - 80ms/step
# Epoch 2754/4000
#
# Epoch 2754: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 252896.9844 - val_loss: 6935.9785 - 536ms/epoch - 77ms/step
# Epoch 2755/4000
#
# Epoch 2755: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 261270.2344 - val_loss: 5587.9326 - 502ms/epoch - 72ms/step
# Epoch 2756/4000
#
# Epoch 2756: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 254050.9844 - val_loss: 4866.4263 - 513ms/epoch - 73ms/step
# Epoch 2757/4000
#
# Epoch 2757: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 271580.0312 - val_loss: 5936.5830 - 531ms/epoch - 76ms/step
# Epoch 2758/4000
#
# Epoch 2758: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 264027.9688 - val_loss: 5015.0913 - 495ms/epoch - 71ms/step
# Epoch 2759/4000
#
# Epoch 2759: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 242412.9531 - val_loss: 5115.7515 - 509ms/epoch - 73ms/step
# Epoch 2760/4000
#
# Epoch 2760: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 267137.1875 - val_loss: 5804.4785 - 514ms/epoch - 73ms/step
# Epoch 2761/4000
#
# Epoch 2761: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 252232.0781 - val_loss: 5101.1455 - 553ms/epoch - 79ms/step
# Epoch 2762/4000
#
# Epoch 2762: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 272061.0625 - val_loss: 5521.2251 - 496ms/epoch - 71ms/step
# Epoch 2763/4000
#
# Epoch 2763: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 245226.3125 - val_loss: 6030.4355 - 505ms/epoch - 72ms/step
# Epoch 2764/4000
#
# Epoch 2764: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 250413.2031 - val_loss: 5944.8872 - 495ms/epoch - 71ms/step
# Epoch 2765/4000
#
# Epoch 2765: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 232063.2344 - val_loss: 6379.1548 - 501ms/epoch - 72ms/step
# Epoch 2766/4000
#
# Epoch 2766: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 270290.6250 - val_loss: 5442.1914 - 513ms/epoch - 73ms/step
# Epoch 2767/4000
#
# Epoch 2767: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 241134.2031 - val_loss: 6893.5796 - 591ms/epoch - 84ms/step
# Epoch 2768/4000
#
# Epoch 2768: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 234135.4219 - val_loss: 5946.7271 - 504ms/epoch - 72ms/step
# Epoch 2769/4000
#
# Epoch 2769: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 281487.4688 - val_loss: 4879.2085 - 504ms/epoch - 72ms/step
# Epoch 2770/4000
#
# Epoch 2770: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 252920.7344 - val_loss: 6051.2749 - 738ms/epoch - 105ms/step
# Epoch 2771/4000
#
# Epoch 2771: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 302297.2500 - val_loss: 10627.2881 - 1s/epoch - 152ms/step
# Epoch 2772/4000
#
# Epoch 2772: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 270592.5312 - val_loss: 5451.8252 - 1s/epoch - 151ms/step
# Epoch 2773/4000
#
# Epoch 2773: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 256785.9844 - val_loss: 5027.0977 - 1s/epoch - 147ms/step
# Epoch 2774/4000
#
# Epoch 2774: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 271821.9688 - val_loss: 4970.9727 - 999ms/epoch - 143ms/step
# Epoch 2775/4000
#
# Epoch 2775: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 247634.6875 - val_loss: 5094.3403 - 947ms/epoch - 135ms/step
# Epoch 2776/4000
#
# Epoch 2776: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 258824.3281 - val_loss: 5297.2349 - 572ms/epoch - 82ms/step
# Epoch 2777/4000
#
# Epoch 2777: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 248286.7500 - val_loss: 7573.2314 - 492ms/epoch - 70ms/step
# Epoch 2778/4000
#
# Epoch 2778: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 295110.5000 - val_loss: 4967.9404 - 554ms/epoch - 79ms/step
# Epoch 2779/4000
#
# Epoch 2779: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 256414.7344 - val_loss: 5884.5005 - 560ms/epoch - 80ms/step
# Epoch 2780/4000
#
# Epoch 2780: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 253808.3125 - val_loss: 7460.8916 - 522ms/epoch - 75ms/step
# Epoch 2781/4000
#
# Epoch 2781: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 262333.4062 - val_loss: 10378.8535 - 493ms/epoch - 70ms/step
# Epoch 2782/4000
#
# Epoch 2782: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 263364.1875 - val_loss: 5027.4570 - 504ms/epoch - 72ms/step
# Epoch 2783/4000
#
# Epoch 2783: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 267727.5625 - val_loss: 13886.8545 - 492ms/epoch - 70ms/step
# Epoch 2784/4000
#
# Epoch 2784: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 261154.7344 - val_loss: 7329.4712 - 500ms/epoch - 71ms/step
# Epoch 2785/4000
#
# Epoch 2785: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 248481.5156 - val_loss: 5448.6943 - 492ms/epoch - 70ms/step
# Epoch 2786/4000
#
# Epoch 2786: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 262432.6250 - val_loss: 5087.3564 - 525ms/epoch - 75ms/step
# Epoch 2787/4000
#
# Epoch 2787: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 247321.3125 - val_loss: 6617.1045 - 495ms/epoch - 71ms/step
# Epoch 2788/4000
#
# Epoch 2788: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 260915.2344 - val_loss: 5741.5444 - 513ms/epoch - 73ms/step
# Epoch 2789/4000
#
# Epoch 2789: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269415.0625 - val_loss: 6388.3369 - 526ms/epoch - 75ms/step
# Epoch 2790/4000
#
# Epoch 2790: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 239961.6250 - val_loss: 9483.0908 - 504ms/epoch - 72ms/step
# Epoch 2791/4000
#
# Epoch 2791: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 265902.2812 - val_loss: 7877.3213 - 490ms/epoch - 70ms/step
# Epoch 2792/4000
#
# Epoch 2792: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269517.9688 - val_loss: 5867.0361 - 534ms/epoch - 76ms/step
# Epoch 2793/4000
#
# Epoch 2793: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 290545.9062 - val_loss: 5951.0854 - 500ms/epoch - 71ms/step
# Epoch 2794/4000
#
# Epoch 2794: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 245643.2344 - val_loss: 6291.1597 - 510ms/epoch - 73ms/step
# Epoch 2795/4000
#
# Epoch 2795: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 268087.3438 - val_loss: 5730.2876 - 724ms/epoch - 103ms/step
# Epoch 2796/4000
#
# Epoch 2796: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 258642.9062 - val_loss: 5706.6338 - 1s/epoch - 159ms/step
# Epoch 2797/4000
#
# Epoch 2797: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 262872.3750 - val_loss: 5167.1509 - 1s/epoch - 155ms/step
# Epoch 2798/4000
#
# Epoch 2798: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 267898.7500 - val_loss: 11805.7588 - 1s/epoch - 146ms/step
# Epoch 2799/4000
#
# Epoch 2799: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 272691.6250 - val_loss: 6151.7515 - 1s/epoch - 151ms/step
# Epoch 2800/4000
#
# Epoch 2800: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 263617.0312 - val_loss: 11158.3164 - 948ms/epoch - 135ms/step
# Epoch 2801/4000
#
# Epoch 2801: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 278209.8438 - val_loss: 9653.2363 - 488ms/epoch - 70ms/step
# Epoch 2802/4000
#
# Epoch 2802: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 273818.7500 - val_loss: 5294.7441 - 547ms/epoch - 78ms/step
# Epoch 2803/4000
#
# Epoch 2803: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 268964.5000 - val_loss: 5875.7944 - 495ms/epoch - 71ms/step
# Epoch 2804/4000
#
# Epoch 2804: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 253682.8594 - val_loss: 6234.0508 - 510ms/epoch - 73ms/step
# Epoch 2805/4000
#
# Epoch 2805: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 268131.0312 - val_loss: 7120.9771 - 512ms/epoch - 73ms/step
# Epoch 2806/4000
#
# Epoch 2806: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 271178.9062 - val_loss: 5360.5225 - 531ms/epoch - 76ms/step
# Epoch 2807/4000
#
# Epoch 2807: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 265295.1562 - val_loss: 6114.5771 - 484ms/epoch - 69ms/step
# Epoch 2808/4000
#
# Epoch 2808: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 276181.6250 - val_loss: 6293.8257 - 547ms/epoch - 78ms/step
# Epoch 2809/4000
#
# Epoch 2809: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269312.9688 - val_loss: 5104.4653 - 510ms/epoch - 73ms/step
# Epoch 2810/4000
#
# Epoch 2810: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 256239.4531 - val_loss: 6840.8672 - 533ms/epoch - 76ms/step
# Epoch 2811/4000
#
# Epoch 2811: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 272947.0625 - val_loss: 22278.4688 - 483ms/epoch - 69ms/step
# Epoch 2812/4000
#
# Epoch 2812: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 249516.5156 - val_loss: 9554.0039 - 543ms/epoch - 78ms/step
# Epoch 2813/4000
#
# Epoch 2813: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 304532.8438 - val_loss: 10335.3584 - 536ms/epoch - 77ms/step
# Epoch 2814/4000
#
# Epoch 2814: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 258343.6562 - val_loss: 7923.5493 - 512ms/epoch - 73ms/step
# Epoch 2815/4000
#
# Epoch 2815: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 267383.0625 - val_loss: 5876.7173 - 478ms/epoch - 68ms/step
# Epoch 2816/4000
#
# Epoch 2816: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 295647.7500 - val_loss: 6218.2705 - 500ms/epoch - 71ms/step
# Epoch 2817/4000
#
# Epoch 2817: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 264231.8438 - val_loss: 5913.4985 - 540ms/epoch - 77ms/step
# Epoch 2818/4000
#
# Epoch 2818: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 265037.5000 - val_loss: 6652.2461 - 527ms/epoch - 75ms/step
# Epoch 2819/4000
#
# Epoch 2819: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 256688.7656 - val_loss: 7171.5103 - 494ms/epoch - 71ms/step
# Epoch 2820/4000
#
# Epoch 2820: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 241584.8750 - val_loss: 8452.9619 - 908ms/epoch - 130ms/step
# Epoch 2821/4000
#
# Epoch 2821: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 272846.9375 - val_loss: 6745.2119 - 1s/epoch - 157ms/step
# Epoch 2822/4000
#
# Epoch 2822: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 258471.5781 - val_loss: 17820.0430 - 1s/epoch - 163ms/step
# Epoch 2823/4000
#
# Epoch 2823: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 237512.8906 - val_loss: 9248.6963 - 937ms/epoch - 134ms/step
# Epoch 2824/4000
#
# Epoch 2824: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269594.0312 - val_loss: 5753.2412 - 1s/epoch - 153ms/step
# Epoch 2825/4000
#
# Epoch 2825: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 272121.8125 - val_loss: 6484.7017 - 828ms/epoch - 118ms/step
# Epoch 2826/4000
#
# Epoch 2826: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 259096.3125 - val_loss: 6508.1299 - 504ms/epoch - 72ms/step
# Epoch 2827/4000
#
# Epoch 2827: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 241950.0312 - val_loss: 5906.0952 - 510ms/epoch - 73ms/step
# Epoch 2828/4000
#
# Epoch 2828: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 229642.4219 - val_loss: 5985.1841 - 512ms/epoch - 73ms/step
# Epoch 2829/4000
#
# Epoch 2829: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 251085.2969 - val_loss: 5698.9023 - 483ms/epoch - 69ms/step
# Epoch 2830/4000
#
# Epoch 2830: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 295836.7188 - val_loss: 5604.4590 - 507ms/epoch - 72ms/step
# Epoch 2831/4000
#
# Epoch 2831: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 257291.5938 - val_loss: 5946.9399 - 496ms/epoch - 71ms/step
# Epoch 2832/4000
#
# Epoch 2832: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 263966.3750 - val_loss: 5608.8892 - 527ms/epoch - 75ms/step
# Epoch 2833/4000
#
# Epoch 2833: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 229444.7031 - val_loss: 9588.7598 - 724ms/epoch - 103ms/step
# Epoch 2834/4000
#
# Epoch 2834: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 269154.1562 - val_loss: 7225.8799 - 499ms/epoch - 71ms/step
# Epoch 2835/4000
#
# Epoch 2835: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 290418.1875 - val_loss: 5494.7275 - 489ms/epoch - 70ms/step
# Epoch 2836/4000
#
# Epoch 2836: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 254912.9062 - val_loss: 5105.4326 - 530ms/epoch - 76ms/step
# Epoch 2837/4000
#
# Epoch 2837: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 221701.7344 - val_loss: 6995.4731 - 483ms/epoch - 69ms/step
# Epoch 2838/4000
#
# Epoch 2838: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 273032.9375 - val_loss: 5169.6138 - 558ms/epoch - 80ms/step
# Epoch 2839/4000
#
# Epoch 2839: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 243645.3750 - val_loss: 5769.1211 - 493ms/epoch - 70ms/step
# Epoch 2840/4000
#
# Epoch 2840: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 267495.0938 - val_loss: 5311.4795 - 525ms/epoch - 75ms/step
# Epoch 2841/4000
#
# Epoch 2841: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 239028.5312 - val_loss: 7938.2812 - 516ms/epoch - 74ms/step
# Epoch 2842/4000
#
# Epoch 2842: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 267653.3750 - val_loss: 5915.5776 - 563ms/epoch - 80ms/step
# Epoch 2843/4000
#
# Epoch 2843: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 260452.4062 - val_loss: 9087.6748 - 531ms/epoch - 76ms/step
# Epoch 2844/4000
#
# Epoch 2844: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 256367.8438 - val_loss: 6243.8818 - 777ms/epoch - 111ms/step
# Epoch 2845/4000
#
# Epoch 2845: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 255030.4844 - val_loss: 6359.0542 - 1s/epoch - 150ms/step
# Epoch 2846/4000
#
# Epoch 2846: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 273811.4062 - val_loss: 6399.5610 - 1s/epoch - 147ms/step
# Epoch 2847/4000
#
# Epoch 2847: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 262985.4688 - val_loss: 7208.8872 - 1s/epoch - 146ms/step
# Epoch 2848/4000
#
# Epoch 2848: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 240906.6562 - val_loss: 6213.6006 - 851ms/epoch - 122ms/step
# Epoch 2849/4000
#
# Epoch 2849: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 270736.9062 - val_loss: 5702.1895 - 990ms/epoch - 141ms/step
# Epoch 2850/4000
#
# Epoch 2850: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 234723.6719 - val_loss: 5522.1597 - 608ms/epoch - 87ms/step
# Epoch 2851/4000
#
# Epoch 2851: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 254467.0781 - val_loss: 7272.1250 - 538ms/epoch - 77ms/step
# Epoch 2852/4000
#
# Epoch 2852: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 268826.0312 - val_loss: 5714.3584 - 506ms/epoch - 72ms/step
# Epoch 2853/4000
#
# Epoch 2853: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 265322.5625 - val_loss: 5605.8984 - 502ms/epoch - 72ms/step
# Epoch 2854/4000
#
# Epoch 2854: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 273595.3438 - val_loss: 5362.7314 - 499ms/epoch - 71ms/step
# Epoch 2855/4000
#
# Epoch 2855: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 248261.8906 - val_loss: 5463.3472 - 511ms/epoch - 73ms/step
# Epoch 2856/4000
#
# Epoch 2856: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 278616.5312 - val_loss: 8881.6318 - 503ms/epoch - 72ms/step
# Epoch 2857/4000
#
# Epoch 2857: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 253623.4844 - val_loss: 8335.0352 - 490ms/epoch - 70ms/step
# Epoch 2858/4000
#
# Epoch 2858: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 268158.2812 - val_loss: 6073.6646 - 511ms/epoch - 73ms/step
# Epoch 2859/4000
#
# Epoch 2859: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 218685.0156 - val_loss: 5347.7993 - 540ms/epoch - 77ms/step
# Epoch 2860/4000
#
# Epoch 2860: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 274229.2500 - val_loss: 5246.4419 - 535ms/epoch - 76ms/step
# Epoch 2861/4000
#
# Epoch 2861: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 248598.3750 - val_loss: 7527.5444 - 506ms/epoch - 72ms/step
# Epoch 2862/4000
#
# Epoch 2862: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 273375.6250 - val_loss: 5453.8335 - 537ms/epoch - 77ms/step
# Epoch 2863/4000
#
# Epoch 2863: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269620.6562 - val_loss: 4995.4551 - 508ms/epoch - 73ms/step
# Epoch 2864/4000
#
# Epoch 2864: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 249176.1875 - val_loss: 6324.7500 - 530ms/epoch - 76ms/step
# Epoch 2865/4000
#
# Epoch 2865: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 292797.1875 - val_loss: 6349.1914 - 496ms/epoch - 71ms/step
# Epoch 2866/4000
#
# Epoch 2866: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 254086.0781 - val_loss: 7271.3188 - 519ms/epoch - 74ms/step
# Epoch 2867/4000
#
# Epoch 2867: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 214657.2969 - val_loss: 11282.9961 - 505ms/epoch - 72ms/step
# Epoch 2868/4000
#
# Epoch 2868: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 242423.4219 - val_loss: 7884.6899 - 532ms/epoch - 76ms/step
# Epoch 2869/4000
#
# Epoch 2869: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 256888.0312 - val_loss: 5679.0820 - 871ms/epoch - 124ms/step
# Epoch 2870/4000
#
# Epoch 2870: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 246174.9531 - val_loss: 4980.9922 - 1s/epoch - 144ms/step
# Epoch 2871/4000
#
# Epoch 2871: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 233181.7656 - val_loss: 4988.9614 - 1s/epoch - 149ms/step
# Epoch 2872/4000
#
# Epoch 2872: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 264746.8125 - val_loss: 6722.3599 - 1s/epoch - 144ms/step
# Epoch 2873/4000
#
# Epoch 2873: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 286290.5938 - val_loss: 6988.9194 - 1s/epoch - 144ms/step
# Epoch 2874/4000
#
# Epoch 2874: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 283339.7812 - val_loss: 5035.1128 - 849ms/epoch - 121ms/step
# Epoch 2875/4000
#
# Epoch 2875: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 227002.5469 - val_loss: 9299.7275 - 564ms/epoch - 81ms/step
# Epoch 2876/4000
#
# Epoch 2876: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 272367.9688 - val_loss: 9759.2393 - 515ms/epoch - 74ms/step
# Epoch 2877/4000
#
# Epoch 2877: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 262239.7500 - val_loss: 4985.4629 - 558ms/epoch - 80ms/step
# Epoch 2878/4000
#
# Epoch 2878: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 256960.9531 - val_loss: 5298.6484 - 521ms/epoch - 74ms/step
# Epoch 2879/4000
#
# Epoch 2879: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 288641.1562 - val_loss: 5923.0142 - 520ms/epoch - 74ms/step
# Epoch 2880/4000
#
# Epoch 2880: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 290363.1562 - val_loss: 4992.0767 - 507ms/epoch - 72ms/step
# Epoch 2881/4000
#
# Epoch 2881: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 257209.5469 - val_loss: 4997.4116 - 526ms/epoch - 75ms/step
# Epoch 2882/4000
#
# Epoch 2882: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 248908.5469 - val_loss: 6495.7271 - 488ms/epoch - 70ms/step
# Epoch 2883/4000
#
# Epoch 2883: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 259929.9062 - val_loss: 6939.2271 - 494ms/epoch - 71ms/step
# Epoch 2884/4000
#
# Epoch 2884: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 280024.1562 - val_loss: 5882.9819 - 541ms/epoch - 77ms/step
# Epoch 2885/4000
#
# Epoch 2885: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 271612.9062 - val_loss: 5770.3838 - 518ms/epoch - 74ms/step
# Epoch 2886/4000
#
# Epoch 2886: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 266014.0938 - val_loss: 5746.7817 - 564ms/epoch - 81ms/step
# Epoch 2887/4000
#
# Epoch 2887: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 273923.8125 - val_loss: 5647.2900 - 511ms/epoch - 73ms/step
# Epoch 2888/4000
#
# Epoch 2888: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 249868.2188 - val_loss: 5596.4668 - 541ms/epoch - 77ms/step
# Epoch 2889/4000
#
# Epoch 2889: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 262272.0312 - val_loss: 5536.7627 - 525ms/epoch - 75ms/step
# Epoch 2890/4000
#
# Epoch 2890: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 246431.9844 - val_loss: 6027.0610 - 498ms/epoch - 71ms/step
# Epoch 2891/4000
#
# Epoch 2891: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 254528.4531 - val_loss: 5187.6958 - 511ms/epoch - 73ms/step
# Epoch 2892/4000
#
# Epoch 2892: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 255466.4688 - val_loss: 5327.1392 - 522ms/epoch - 75ms/step
# Epoch 2893/4000
#
# Epoch 2893: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269162.4688 - val_loss: 5058.3149 - 513ms/epoch - 73ms/step
# Epoch 2894/4000
#
# Epoch 2894: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 262240.6875 - val_loss: 5423.3857 - 989ms/epoch - 141ms/step
# Epoch 2895/4000
#
# Epoch 2895: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 222813.1406 - val_loss: 5630.8560 - 1s/epoch - 148ms/step
# Epoch 2896/4000
#
# Epoch 2896: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 233918.2188 - val_loss: 8378.6318 - 1s/epoch - 151ms/step
# Epoch 2897/4000
#
# Epoch 2897: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 260300.0469 - val_loss: 6726.7251 - 898ms/epoch - 128ms/step
# Epoch 2898/4000
#
# Epoch 2898: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 268021.8750 - val_loss: 4855.0254 - 1s/epoch - 158ms/step
# Epoch 2899/4000
#
# Epoch 2899: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 256207.3438 - val_loss: 5697.2646 - 757ms/epoch - 108ms/step
# Epoch 2900/4000
#
# Epoch 2900: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 264165.9688 - val_loss: 4922.6982 - 529ms/epoch - 76ms/step
# Epoch 2901/4000
#
# Epoch 2901: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 257222.8125 - val_loss: 7507.6714 - 502ms/epoch - 72ms/step
# Epoch 2902/4000
#
# Epoch 2902: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 270798.1250 - val_loss: 5050.6826 - 536ms/epoch - 77ms/step
# Epoch 2903/4000
#
# Epoch 2903: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 239631.2188 - val_loss: 5154.7520 - 501ms/epoch - 72ms/step
# Epoch 2904/4000
#
# Epoch 2904: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 257516.2656 - val_loss: 5982.1465 - 505ms/epoch - 72ms/step
# Epoch 2905/4000
#
# Epoch 2905: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 263673.5312 - val_loss: 8572.2139 - 509ms/epoch - 73ms/step
# Epoch 2906/4000
#
# Epoch 2906: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 271233.0312 - val_loss: 8414.9131 - 480ms/epoch - 69ms/step
# Epoch 2907/4000
#
# Epoch 2907: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 284349.5938 - val_loss: 5509.5713 - 593ms/epoch - 85ms/step
# Epoch 2908/4000
#
# Epoch 2908: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 259695.3594 - val_loss: 5447.0474 - 519ms/epoch - 74ms/step
# Epoch 2909/4000
#
# Epoch 2909: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 236872.0938 - val_loss: 6591.2920 - 559ms/epoch - 80ms/step
# Epoch 2910/4000
#
# Epoch 2910: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 281835.9375 - val_loss: 7020.9316 - 492ms/epoch - 70ms/step
# Epoch 2911/4000
#
# Epoch 2911: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 271237.6875 - val_loss: 5404.3149 - 518ms/epoch - 74ms/step
# Epoch 2912/4000
#
# Epoch 2912: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 247301.7812 - val_loss: 9350.5908 - 511ms/epoch - 73ms/step
# Epoch 2913/4000
#
# Epoch 2913: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 251534.6875 - val_loss: 10912.7070 - 523ms/epoch - 75ms/step
# Epoch 2914/4000
#
# Epoch 2914: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 242146.1875 - val_loss: 7306.6548 - 506ms/epoch - 72ms/step
# Epoch 2915/4000
#
# Epoch 2915: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 243306.7344 - val_loss: 46541.8555 - 547ms/epoch - 78ms/step
# Epoch 2916/4000
#
# Epoch 2916: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 260957.2656 - val_loss: 4918.7378 - 527ms/epoch - 75ms/step
# Epoch 2917/4000
#
# Epoch 2917: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 271704.5312 - val_loss: 5077.8701 - 495ms/epoch - 71ms/step
# Epoch 2918/4000
#
# Epoch 2918: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 261674.0312 - val_loss: 4897.5444 - 622ms/epoch - 89ms/step
# Epoch 2919/4000
#
# Epoch 2919: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 284453.6875 - val_loss: 5063.8066 - 998ms/epoch - 143ms/step
# Epoch 2920/4000
#
# Epoch 2920: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269180.9688 - val_loss: 5307.1724 - 1s/epoch - 145ms/step
# Epoch 2921/4000
#
# Epoch 2921: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 270603.8438 - val_loss: 5357.0244 - 897ms/epoch - 128ms/step
# Epoch 2922/4000
#
# Epoch 2922: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 264541.5000 - val_loss: 6864.0088 - 1s/epoch - 155ms/step
# Epoch 2923/4000
#
# Epoch 2923: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 243380.8594 - val_loss: 5762.4414 - 989ms/epoch - 141ms/step
# Epoch 2924/4000
#
# Epoch 2924: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 260960.3438 - val_loss: 5016.2432 - 713ms/epoch - 102ms/step
# Epoch 2925/4000
#
# Epoch 2925: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 277315.5312 - val_loss: 5437.2524 - 505ms/epoch - 72ms/step
# Epoch 2926/4000
#
# Epoch 2926: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269731.6250 - val_loss: 5941.9458 - 526ms/epoch - 75ms/step
# Epoch 2927/4000
#
# Epoch 2927: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 265326.1562 - val_loss: 9841.2969 - 502ms/epoch - 72ms/step
# Epoch 2928/4000
#
# Epoch 2928: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 255647.9062 - val_loss: 18200.7090 - 509ms/epoch - 73ms/step
# Epoch 2929/4000
#
# Epoch 2929: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 277271.1875 - val_loss: 8363.9736 - 512ms/epoch - 73ms/step
# Epoch 2930/4000
#
# Epoch 2930: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 258772.3125 - val_loss: 6581.0791 - 519ms/epoch - 74ms/step
# Epoch 2931/4000
#
# Epoch 2931: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 258995.1250 - val_loss: 8496.2373 - 543ms/epoch - 78ms/step
# Epoch 2932/4000
#
# Epoch 2932: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 278144.2500 - val_loss: 7443.1841 - 549ms/epoch - 78ms/step
# Epoch 2933/4000
#
# Epoch 2933: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 254951.2656 - val_loss: 6009.0190 - 504ms/epoch - 72ms/step
# Epoch 2934/4000
#
# Epoch 2934: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 246863.9062 - val_loss: 9737.4102 - 516ms/epoch - 74ms/step
# Epoch 2935/4000
#
# Epoch 2935: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 251582.2500 - val_loss: 15141.4307 - 495ms/epoch - 71ms/step
# Epoch 2936/4000
#
# Epoch 2936: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 271459.7188 - val_loss: 5901.7915 - 496ms/epoch - 71ms/step
# Epoch 2937/4000
#
# Epoch 2937: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 303235.9062 - val_loss: 5425.5396 - 511ms/epoch - 73ms/step
# Epoch 2938/4000
#
# Epoch 2938: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 273071.9062 - val_loss: 10527.7656 - 492ms/epoch - 70ms/step
# Epoch 2939/4000
#
# Epoch 2939: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 262306.9375 - val_loss: 9985.7109 - 522ms/epoch - 75ms/step
# Epoch 2940/4000
#
# Epoch 2940: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 255107.3438 - val_loss: 18856.1836 - 523ms/epoch - 75ms/step
# Epoch 2941/4000
#
# Epoch 2941: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 251344.7969 - val_loss: 9179.9287 - 555ms/epoch - 79ms/step
# Epoch 2942/4000
#
# Epoch 2942: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 265887.3750 - val_loss: 8636.4424 - 513ms/epoch - 73ms/step
# Epoch 2943/4000
#
# Epoch 2943: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 254623.4062 - val_loss: 10586.7285 - 636ms/epoch - 91ms/step
# Epoch 2944/4000
#
# Epoch 2944: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 257124.2031 - val_loss: 4904.1011 - 1s/epoch - 158ms/step
# Epoch 2945/4000
#
# Epoch 2945: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 272564.6562 - val_loss: 10145.5791 - 1s/epoch - 152ms/step
# Epoch 2946/4000
#
# Epoch 2946: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 264395.5938 - val_loss: 13757.0820 - 955ms/epoch - 136ms/step
# Epoch 2947/4000
#
# Epoch 2947: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 270427.9688 - val_loss: 9036.4736 - 1s/epoch - 149ms/step
# Epoch 2948/4000
#
# Epoch 2948: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 254083.1094 - val_loss: 14580.6572 - 956ms/epoch - 137ms/step
# Epoch 2949/4000
#
# Epoch 2949: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 260159.3438 - val_loss: 10335.9961 - 616ms/epoch - 88ms/step
# Epoch 2950/4000
#
# Epoch 2950: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 274971.0938 - val_loss: 10169.3613 - 490ms/epoch - 70ms/step
# Epoch 2951/4000
#
# Epoch 2951: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 238671.0781 - val_loss: 17470.1230 - 533ms/epoch - 76ms/step
# Epoch 2952/4000
#
# Epoch 2952: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 274884.8750 - val_loss: 10153.7812 - 499ms/epoch - 71ms/step
# Epoch 2953/4000
#
# Epoch 2953: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 289044.8125 - val_loss: 11096.3623 - 501ms/epoch - 72ms/step
# Epoch 2954/4000
#
# Epoch 2954: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 280788.9062 - val_loss: 16394.4512 - 533ms/epoch - 76ms/step
# Epoch 2955/4000
#
# Epoch 2955: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 268566.5000 - val_loss: 10558.2949 - 537ms/epoch - 77ms/step
# Epoch 2956/4000
#
# Epoch 2956: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 260722.8750 - val_loss: 7700.0435 - 523ms/epoch - 75ms/step
# Epoch 2957/4000
#
# Epoch 2957: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 290768.2812 - val_loss: 7958.1753 - 494ms/epoch - 71ms/step
# Epoch 2958/4000
#
# Epoch 2958: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 255261.5156 - val_loss: 9688.0137 - 551ms/epoch - 79ms/step
# Epoch 2959/4000
#
# Epoch 2959: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269760.5000 - val_loss: 8478.5693 - 516ms/epoch - 74ms/step
# Epoch 2960/4000
#
# Epoch 2960: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 237776.5781 - val_loss: 11491.0996 - 493ms/epoch - 70ms/step
# Epoch 2961/4000
#
# Epoch 2961: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 272172.0938 - val_loss: 18479.5156 - 582ms/epoch - 83ms/step
# Epoch 2962/4000
#
# Epoch 2962: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 258900.7344 - val_loss: 21457.1504 - 521ms/epoch - 74ms/step
# Epoch 2963/4000
#
# Epoch 2963: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 271735.3125 - val_loss: 15844.2529 - 543ms/epoch - 78ms/step
# Epoch 2964/4000
#
# Epoch 2964: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269886.0938 - val_loss: 19538.5605 - 509ms/epoch - 73ms/step
# Epoch 2965/4000
#
# Epoch 2965: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 243238.8906 - val_loss: 9258.4414 - 545ms/epoch - 78ms/step
# Epoch 2966/4000
#
# Epoch 2966: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 280276.0312 - val_loss: 7510.9805 - 500ms/epoch - 71ms/step
# Epoch 2967/4000
#
# Epoch 2967: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 251922.6406 - val_loss: 13749.6182 - 509ms/epoch - 73ms/step
# Epoch 2968/4000
#
# Epoch 2968: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 237925.9531 - val_loss: 9528.9160 - 915ms/epoch - 131ms/step
# Epoch 2969/4000
#
# Epoch 2969: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 236006.3281 - val_loss: 8547.9043 - 1s/epoch - 158ms/step
# Epoch 2970/4000
#
# Epoch 2970: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 240165.3594 - val_loss: 12915.3203 - 1s/epoch - 156ms/step
# Epoch 2971/4000
#
# Epoch 2971: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 270968.0625 - val_loss: 10257.6504 - 949ms/epoch - 136ms/step
# Epoch 2972/4000
#
# Epoch 2972: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 261488.5156 - val_loss: 6274.1768 - 1s/epoch - 152ms/step
# Epoch 2973/4000
#
# Epoch 2973: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 244786.1562 - val_loss: 11744.0820 - 791ms/epoch - 113ms/step
# Epoch 2974/4000
#
# Epoch 2974: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 272846.5938 - val_loss: 19547.0703 - 516ms/epoch - 74ms/step
# Epoch 2975/4000
#
# Epoch 2975: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 247998.2031 - val_loss: 16418.9746 - 492ms/epoch - 70ms/step
# Epoch 2976/4000
#
# Epoch 2976: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 252729.0469 - val_loss: 21242.4102 - 503ms/epoch - 72ms/step
# Epoch 2977/4000
#
# Epoch 2977: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 290299.2188 - val_loss: 28640.1680 - 531ms/epoch - 76ms/step
# Epoch 2978/4000
#
# Epoch 2978: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 285842.0312 - val_loss: 5127.8164 - 541ms/epoch - 77ms/step
# Epoch 2979/4000
#
# Epoch 2979: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 283896.6562 - val_loss: 6872.9897 - 499ms/epoch - 71ms/step
# Epoch 2980/4000
#
# Epoch 2980: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 276671.0000 - val_loss: 5726.4883 - 498ms/epoch - 71ms/step
# Epoch 2981/4000
#
# Epoch 2981: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 272765.0312 - val_loss: 14910.4639 - 514ms/epoch - 73ms/step
# Epoch 2982/4000
#
# Epoch 2982: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 251933.3750 - val_loss: 4928.7148 - 547ms/epoch - 78ms/step
# Epoch 2983/4000
#
# Epoch 2983: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 274658.3125 - val_loss: 7435.4951 - 562ms/epoch - 80ms/step
# Epoch 2984/4000
#
# Epoch 2984: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 250841.5625 - val_loss: 8401.9707 - 495ms/epoch - 71ms/step
# Epoch 2985/4000
#
# Epoch 2985: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 268193.2812 - val_loss: 8773.6201 - 494ms/epoch - 71ms/step
# Epoch 2986/4000
#
# Epoch 2986: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 307287.0938 - val_loss: 28069.1484 - 547ms/epoch - 78ms/step
# Epoch 2987/4000
#
# Epoch 2987: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 270339.6250 - val_loss: 17344.4219 - 542ms/epoch - 77ms/step
# Epoch 2988/4000
#
# Epoch 2988: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 245675.7812 - val_loss: 8242.8740 - 620ms/epoch - 89ms/step
# Epoch 2989/4000
#
# Epoch 2989: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 256790.9688 - val_loss: 13008.6631 - 494ms/epoch - 71ms/step
# Epoch 2990/4000
#
# Epoch 2990: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 252100.8438 - val_loss: 11196.5752 - 492ms/epoch - 70ms/step
# Epoch 2991/4000
#
# Epoch 2991: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 254127.1875 - val_loss: 6841.6089 - 508ms/epoch - 73ms/step
# Epoch 2992/4000
#
# Epoch 2992: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 279057.5938 - val_loss: 26176.9805 - 800ms/epoch - 114ms/step
# Epoch 2993/4000
#
# Epoch 2993: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269271.8438 - val_loss: 31475.2188 - 999ms/epoch - 143ms/step
# Epoch 2994/4000
#
# Epoch 2994: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 242348.0156 - val_loss: 6217.5474 - 1s/epoch - 153ms/step
# Epoch 2995/4000
#
# Epoch 2995: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 256919.5781 - val_loss: 10753.4004 - 992ms/epoch - 142ms/step
# Epoch 2996/4000
#
# Epoch 2996: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 260298.4844 - val_loss: 7712.3535 - 1s/epoch - 144ms/step
# Epoch 2997/4000
#
# Epoch 2997: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 275925.6875 - val_loss: 5003.7900 - 922ms/epoch - 132ms/step
# Epoch 2998/4000
#
# Epoch 2998: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 251825.6719 - val_loss: 6471.2563 - 637ms/epoch - 91ms/step
# Epoch 2999/4000
#
# Epoch 2999: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 285948.3750 - val_loss: 6193.9209 - 549ms/epoch - 78ms/step
# Epoch 3000/4000
#
# Epoch 3000: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 261373.7812 - val_loss: 5025.0410 - 495ms/epoch - 71ms/step
# Epoch 3001/4000
#
# Epoch 3001: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 265701.9688 - val_loss: 6182.0205 - 536ms/epoch - 77ms/step
# Epoch 3002/4000
#
# Epoch 3002: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 255959.3750 - val_loss: 12409.9160 - 487ms/epoch - 70ms/step
# Epoch 3003/4000
#
# Epoch 3003: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 237774.9844 - val_loss: 12986.5234 - 586ms/epoch - 84ms/step
# Epoch 3004/4000
#
# Epoch 3004: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 261690.6406 - val_loss: 10882.9131 - 501ms/epoch - 72ms/step
# Epoch 3005/4000
#
# Epoch 3005: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 260916.1875 - val_loss: 10082.1387 - 511ms/epoch - 73ms/step
# Epoch 3006/4000
#
# Epoch 3006: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 277758.0000 - val_loss: 9495.8135 - 485ms/epoch - 69ms/step
# Epoch 3007/4000
#
# Epoch 3007: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269295.4062 - val_loss: 5047.5859 - 524ms/epoch - 75ms/step
# Epoch 3008/4000
#
# Epoch 3008: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 248682.4688 - val_loss: 4909.9150 - 532ms/epoch - 76ms/step
# Epoch 3009/4000
#
# Epoch 3009: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 258518.8906 - val_loss: 6761.3027 - 512ms/epoch - 73ms/step
# Epoch 3010/4000
#
# Epoch 3010: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 234427.9219 - val_loss: 5949.2373 - 522ms/epoch - 75ms/step
# Epoch 3011/4000
#
# Epoch 3011: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 267004.1562 - val_loss: 10402.2510 - 512ms/epoch - 73ms/step
# Epoch 3012/4000
#
# Epoch 3012: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 278276.4688 - val_loss: 6929.1641 - 522ms/epoch - 75ms/step
# Epoch 3013/4000
#
# Epoch 3013: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 267691.2500 - val_loss: 7049.3423 - 542ms/epoch - 77ms/step
# Epoch 3014/4000
#
# Epoch 3014: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 268516.1562 - val_loss: 7107.0610 - 513ms/epoch - 73ms/step
# Epoch 3015/4000
#
# Epoch 3015: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 259075.4375 - val_loss: 8535.3818 - 531ms/epoch - 76ms/step
# Epoch 3016/4000
#
# Epoch 3016: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 254548.1094 - val_loss: 4998.1631 - 497ms/epoch - 71ms/step
# Epoch 3017/4000
#
# Epoch 3017: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 252759.2344 - val_loss: 4774.2231 - 859ms/epoch - 123ms/step
# Epoch 3018/4000
#
# Epoch 3018: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 282344.5000 - val_loss: 6123.1597 - 1s/epoch - 152ms/step
# Epoch 3019/4000
#
# Epoch 3019: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 241601.9531 - val_loss: 4811.2642 - 1s/epoch - 146ms/step
# Epoch 3020/4000
#
# Epoch 3020: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 275626.1875 - val_loss: 10062.5781 - 1s/epoch - 145ms/step
# Epoch 3021/4000
#
# Epoch 3021: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 257376.8906 - val_loss: 13279.2002 - 990ms/epoch - 141ms/step
# Epoch 3022/4000
#
# Epoch 3022: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 297324.0000 - val_loss: 7214.4248 - 988ms/epoch - 141ms/step
# Epoch 3023/4000
#
# Epoch 3023: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 275155.9688 - val_loss: 8285.6426 - 511ms/epoch - 73ms/step
# Epoch 3024/4000
#
# Epoch 3024: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 266431.2500 - val_loss: 5444.4819 - 504ms/epoch - 72ms/step
# Epoch 3025/4000
#
# Epoch 3025: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 208457.2188 - val_loss: 7154.2007 - 520ms/epoch - 74ms/step
# Epoch 3026/4000
#
# Epoch 3026: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 274632.7188 - val_loss: 8979.2744 - 528ms/epoch - 75ms/step
# Epoch 3027/4000
#
# Epoch 3027: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 274375.2812 - val_loss: 5456.3159 - 504ms/epoch - 72ms/step
# Epoch 3028/4000
#
# Epoch 3028: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 262765.7188 - val_loss: 7536.1084 - 551ms/epoch - 79ms/step
# Epoch 3029/4000
#
# Epoch 3029: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 241352.3281 - val_loss: 5051.5796 - 518ms/epoch - 74ms/step
# Epoch 3030/4000
#
# Epoch 3030: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 258363.7344 - val_loss: 5246.0742 - 493ms/epoch - 70ms/step
# Epoch 3031/4000
#
# Epoch 3031: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 235162.5781 - val_loss: 6764.2104 - 544ms/epoch - 78ms/step
# Epoch 3032/4000
#
# Epoch 3032: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 230886.1875 - val_loss: 7429.2397 - 484ms/epoch - 69ms/step
# Epoch 3033/4000
#
# Epoch 3033: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 257381.4062 - val_loss: 4950.1660 - 530ms/epoch - 76ms/step
# Epoch 3034/4000
#
# Epoch 3034: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 252816.2031 - val_loss: 6767.9951 - 498ms/epoch - 71ms/step
# Epoch 3035/4000
#
# Epoch 3035: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 254638.6719 - val_loss: 8273.6943 - 507ms/epoch - 72ms/step
# Epoch 3036/4000
#
# Epoch 3036: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 241991.9062 - val_loss: 5051.2168 - 510ms/epoch - 73ms/step
# Epoch 3037/4000
#
# Epoch 3037: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 273865.0625 - val_loss: 7158.7061 - 518ms/epoch - 74ms/step
# Epoch 3038/4000
#
# Epoch 3038: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 258941.3750 - val_loss: 7485.6440 - 487ms/epoch - 70ms/step
# Epoch 3039/4000
#
# Epoch 3039: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 238898.4688 - val_loss: 8023.4683 - 501ms/epoch - 72ms/step
# Epoch 3040/4000
#
# Epoch 3040: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 242000.9688 - val_loss: 5788.5151 - 521ms/epoch - 74ms/step
# Epoch 3041/4000
#
# Epoch 3041: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 315032.7500 - val_loss: 11809.9473 - 489ms/epoch - 70ms/step
# Epoch 3042/4000
#
# Epoch 3042: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 259493.9219 - val_loss: 18734.6387 - 996ms/epoch - 142ms/step
# Epoch 3043/4000
#
# Epoch 3043: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 239439.0469 - val_loss: 8380.7305 - 1s/epoch - 157ms/step
# Epoch 3044/4000
#
# Epoch 3044: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 299487.3125 - val_loss: 4804.9336 - 1s/epoch - 146ms/step
# Epoch 3045/4000
#
# Epoch 3045: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 228529.0938 - val_loss: 4704.1260 - 972ms/epoch - 139ms/step
# Epoch 3046/4000
#
# Epoch 3046: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 290157.2500 - val_loss: 4717.0405 - 1s/epoch - 148ms/step
# Epoch 3047/4000
#
# Epoch 3047: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 287526.1875 - val_loss: 5658.6523 - 733ms/epoch - 105ms/step
# Epoch 3048/4000
#
# Epoch 3048: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 273270.3125 - val_loss: 6709.9229 - 577ms/epoch - 82ms/step
# Epoch 3049/4000
#
# Epoch 3049: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 253088.9531 - val_loss: 8676.5000 - 534ms/epoch - 76ms/step
# Epoch 3050/4000
#
# Epoch 3050: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 284345.9688 - val_loss: 6953.1836 - 594ms/epoch - 85ms/step
# Epoch 3051/4000
#
# Epoch 3051: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 280904.5000 - val_loss: 8862.7666 - 495ms/epoch - 71ms/step
# Epoch 3052/4000
#
# Epoch 3052: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 257865.2656 - val_loss: 5878.1860 - 514ms/epoch - 73ms/step
# Epoch 3053/4000
#
# Epoch 3053: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 269777.8750 - val_loss: 5037.3931 - 556ms/epoch - 79ms/step
# Epoch 3054/4000
#
# Epoch 3054: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 264247.4688 - val_loss: 5004.8389 - 492ms/epoch - 70ms/step
# Epoch 3055/4000
#
# Epoch 3055: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 270632.9062 - val_loss: 9786.8955 - 532ms/epoch - 76ms/step
# Epoch 3056/4000
#
# Epoch 3056: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 272420.8125 - val_loss: 6839.0273 - 497ms/epoch - 71ms/step
# Epoch 3057/4000
#
# Epoch 3057: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 316269.1875 - val_loss: 7056.3892 - 533ms/epoch - 76ms/step
# Epoch 3058/4000
#
# Epoch 3058: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 258595.4062 - val_loss: 6026.3452 - 531ms/epoch - 76ms/step
# Epoch 3059/4000
#
# Epoch 3059: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 276263.3750 - val_loss: 5353.6733 - 520ms/epoch - 74ms/step
# Epoch 3060/4000
#
# Epoch 3060: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 251186.7656 - val_loss: 5033.8765 - 511ms/epoch - 73ms/step
# Epoch 3061/4000
#
# Epoch 3061: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 257871.5625 - val_loss: 7235.5000 - 536ms/epoch - 77ms/step
# Epoch 3062/4000
#
# Epoch 3062: loss did not improve from 207238.15625
# 7/7 - 0s - loss: 241965.1562 - val_loss: 7267.9941 - 498ms/epoch - 71ms/step
# Epoch 3063/4000
#
# Epoch 3063: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 263594.4688 - val_loss: 7666.3101 - 510ms/epoch - 73ms/step
# Epoch 3064/4000
#
# Epoch 3064: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 284141.7500 - val_loss: 11462.4004 - 503ms/epoch - 72ms/step
# Epoch 3065/4000
#
# Epoch 3065: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 276238.7500 - val_loss: 15954.9697 - 515ms/epoch - 74ms/step
# Epoch 3066/4000
#
# Epoch 3066: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 277212.0312 - val_loss: 12971.7529 - 662ms/epoch - 95ms/step
# Epoch 3067/4000
#
# Epoch 3067: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 285776.7188 - val_loss: 10886.6162 - 1s/epoch - 150ms/step
# Epoch 3068/4000
#
# Epoch 3068: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 263416.7500 - val_loss: 22892.7422 - 1s/epoch - 157ms/step
# Epoch 3069/4000
#
# Epoch 3069: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 256504.3750 - val_loss: 12510.8545 - 979ms/epoch - 140ms/step
# Epoch 3070/4000
#
# Epoch 3070: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 258989.7344 - val_loss: 5537.7817 - 1s/epoch - 151ms/step
# Epoch 3071/4000
#
# Epoch 3071: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 281380.7500 - val_loss: 5174.0840 - 978ms/epoch - 140ms/step
# Epoch 3072/4000
#
# Epoch 3072: loss did not improve from 207238.15625
# 7/7 - 1s - loss: 261945.4219 - val_loss: 9818.2168 - 523ms/epoch - 75ms/step
# Epoch 3073/4000
#
# Epoch 3073: loss did not improve from 207238.15625
# ...
# Epoch 3892/4000
#
# Epoch 3892: loss did not improve from 199819.53125
# 7/7 - 0s - loss: 220553.6250 - val_loss: 4708.2373 - 487ms/epoch - 70ms/step
# Epoch 3893/4000
#
# Epoch 3893: loss did not improve from 199819.53125
# 7/7 - 0s - loss: 215331.3438 - val_loss: 5267.5283 - 500ms/epoch - 71ms/step
# Epoch 3894/4000
#
# Epoch 3894: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 260843.2031 - val_loss: 4710.0425 - 539ms/epoch - 77ms/step
# Epoch 3895/4000
#
# Epoch 3895: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 249949.8906 - val_loss: 8366.0518 - 509ms/epoch - 73ms/step
# Epoch 3896/4000
#
# Epoch 3896: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 265046.0312 - val_loss: 4699.9497 - 525ms/epoch - 75ms/step
# Epoch 3897/4000
#
# Epoch 3897: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 244001.7656 - val_loss: 9153.9639 - 511ms/epoch - 73ms/step
# Epoch 3898/4000
#
# Epoch 3898: loss did not improve from 199819.53125
# 7/7 - 0s - loss: 267571.1875 - val_loss: 5821.1548 - 491ms/epoch - 70ms/step
# Epoch 3899/4000
#
# Epoch 3899: loss did not improve from 199819.53125
# 7/7 - 0s - loss: 237498.4219 - val_loss: 5086.9556 - 491ms/epoch - 70ms/step
# Epoch 3900/4000
#
# Epoch 3900: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 252335.4531 - val_loss: 5209.8667 - 537ms/epoch - 77ms/step
# Epoch 3901/4000
#
# Epoch 3901: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 239174.2188 - val_loss: 4839.7212 - 575ms/epoch - 82ms/step
# Epoch 3902/4000
#
# Epoch 3902: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 228689.3438 - val_loss: 4712.0327 - 561ms/epoch - 80ms/step
# Epoch 3903/4000
#
# Epoch 3903: loss did not improve from 199819.53125
# 7/7 - 0s - loss: 271893.4062 - val_loss: 4736.2827 - 482ms/epoch - 69ms/step
# Epoch 3904/4000
#
# Epoch 3904: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 229681.2188 - val_loss: 5665.9805 - 511ms/epoch - 73ms/step
# Epoch 3905/4000
#
# Epoch 3905: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 238581.9062 - val_loss: 4798.0098 - 511ms/epoch - 73ms/step
# Epoch 3906/4000
#
# Epoch 3906: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 238189.8594 - val_loss: 7920.8711 - 899ms/epoch - 128ms/step
# Epoch 3907/4000
#
# Epoch 3907: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 259140.1875 - val_loss: 6979.0728 - 1s/epoch - 153ms/step
# Epoch 3908/4000
#
# Epoch 3908: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 253484.6562 - val_loss: 5098.2314 - 1s/epoch - 154ms/step
# Epoch 3909/4000
#
# Epoch 3909: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 237418.3750 - val_loss: 4624.1714 - 1s/epoch - 154ms/step
# Epoch 3910/4000
#
# Epoch 3910: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 259624.2500 - val_loss: 4816.3271 - 1s/epoch - 162ms/step
# Epoch 3911/4000
#
# Epoch 3911: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 239659.8750 - val_loss: 5320.9526 - 962ms/epoch - 137ms/step
# Epoch 3912/4000
#
# Epoch 3912: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 275780.8750 - val_loss: 4777.7437 - 586ms/epoch - 84ms/step
# Epoch 3913/4000
#
# Epoch 3913: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 227057.2344 - val_loss: 6232.0786 - 528ms/epoch - 75ms/step
# Epoch 3914/4000
#
# Epoch 3914: loss did not improve from 199819.53125
# 7/7 - 0s - loss: 220442.9688 - val_loss: 8221.5107 - 495ms/epoch - 71ms/step
# Epoch 3915/4000
#
# Epoch 3915: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 256490.0312 - val_loss: 8747.8799 - 518ms/epoch - 74ms/step
# Epoch 3916/4000
#
# Epoch 3916: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 297306.3438 - val_loss: 7845.5078 - 575ms/epoch - 82ms/step
# Epoch 3917/4000
#
# Epoch 3917: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 283594.8438 - val_loss: 5179.8115 - 500ms/epoch - 71ms/step
# Epoch 3918/4000
#
# Epoch 3918: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 232997.4688 - val_loss: 4675.2710 - 568ms/epoch - 81ms/step
# Epoch 3919/4000
#
# Epoch 3919: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 260437.5625 - val_loss: 6783.3818 - 536ms/epoch - 77ms/step
# Epoch 3920/4000
#
# Epoch 3920: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 262345.1562 - val_loss: 5042.3755 - 520ms/epoch - 74ms/step
# Epoch 3921/4000
#
# Epoch 3921: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 224973.8594 - val_loss: 5178.8877 - 547ms/epoch - 78ms/step
# Epoch 3922/4000
#
# Epoch 3922: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 245304.1562 - val_loss: 6445.7119 - 597ms/epoch - 85ms/step
# Epoch 3923/4000
#
# Epoch 3923: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 228720.5469 - val_loss: 6809.4976 - 552ms/epoch - 79ms/step
# Epoch 3924/4000
#
# Epoch 3924: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 257246.8438 - val_loss: 5132.0024 - 529ms/epoch - 76ms/step
# Epoch 3925/4000
#
# Epoch 3925: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 241325.8594 - val_loss: 5766.1123 - 542ms/epoch - 77ms/step
# Epoch 3926/4000
#
# Epoch 3926: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 241936.3281 - val_loss: 6200.3994 - 597ms/epoch - 85ms/step
# Epoch 3927/4000
#
# Epoch 3927: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 272081.2812 - val_loss: 4617.1152 - 531ms/epoch - 76ms/step
# Epoch 3928/4000
#
# Epoch 3928: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 258930.4531 - val_loss: 4993.3999 - 574ms/epoch - 82ms/step
# Epoch 3929/4000
#
# Epoch 3929: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 215771.9531 - val_loss: 5833.4414 - 534ms/epoch - 76ms/step
# Epoch 3930/4000
#
# Epoch 3930: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 230299.3281 - val_loss: 4677.2935 - 780ms/epoch - 111ms/step
# Epoch 3931/4000
#
# Epoch 3931: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 243559.4688 - val_loss: 4774.6479 - 1s/epoch - 148ms/step
# Epoch 3932/4000
#
# Epoch 3932: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 222889.0469 - val_loss: 4802.4102 - 1s/epoch - 145ms/step
# Epoch 3933/4000
#
# Epoch 3933: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 235075.8125 - val_loss: 5740.3765 - 970ms/epoch - 139ms/step
# Epoch 3934/4000
#
# Epoch 3934: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 232648.8438 - val_loss: 4637.8867 - 940ms/epoch - 134ms/step
# Epoch 3935/4000
#
# Epoch 3935: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 257061.2500 - val_loss: 6458.5015 - 1s/epoch - 147ms/step
# Epoch 3936/4000
#
# Epoch 3936: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 229913.8125 - val_loss: 4845.0986 - 679ms/epoch - 97ms/step
# Epoch 3937/4000
#
# Epoch 3937: loss did not improve from 199819.53125
# 7/7 - 0s - loss: 203357.9062 - val_loss: 5545.7642 - 484ms/epoch - 69ms/step
# Epoch 3938/4000
#
# Epoch 3938: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 268085.3125 - val_loss: 4987.5059 - 543ms/epoch - 78ms/step
# Epoch 3939/4000
#
# Epoch 3939: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 244312.0156 - val_loss: 4750.2676 - 534ms/epoch - 76ms/step
# Epoch 3940/4000
#
# Epoch 3940: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 231922.9531 - val_loss: 6042.5522 - 575ms/epoch - 82ms/step
# Epoch 3941/4000
#
# Epoch 3941: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 224780.9531 - val_loss: 10471.8633 - 515ms/epoch - 74ms/step
# Epoch 3942/4000
#
# Epoch 3942: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 246081.3594 - val_loss: 4630.7549 - 540ms/epoch - 77ms/step
# Epoch 3943/4000
#
# Epoch 3943: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 258845.3594 - val_loss: 4847.8994 - 509ms/epoch - 73ms/step
# Epoch 3944/4000
#
# Epoch 3944: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 261174.0312 - val_loss: 6578.8208 - 559ms/epoch - 80ms/step
# Epoch 3945/4000
#
# Epoch 3945: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 261173.8125 - val_loss: 7239.8931 - 533ms/epoch - 76ms/step
# Epoch 3946/4000
#
# Epoch 3946: loss did not improve from 199819.53125
# 7/7 - 0s - loss: 223643.1406 - val_loss: 4586.5679 - 491ms/epoch - 70ms/step
# Epoch 3947/4000
#
# Epoch 3947: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 230513.6875 - val_loss: 4614.4253 - 585ms/epoch - 84ms/step
# Epoch 3948/4000
#
# Epoch 3948: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 213442.2500 - val_loss: 5050.7441 - 516ms/epoch - 74ms/step
# Epoch 3949/4000
#
# Epoch 3949: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 270402.3125 - val_loss: 4632.2896 - 551ms/epoch - 79ms/step
# Epoch 3950/4000
#
# Epoch 3950: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 244405.7031 - val_loss: 5878.6025 - 569ms/epoch - 81ms/step
# Epoch 3951/4000
#
# Epoch 3951: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 230113.0000 - val_loss: 6327.5752 - 520ms/epoch - 74ms/step
# Epoch 3952/4000
#
# Epoch 3952: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 226721.6406 - val_loss: 4645.6758 - 541ms/epoch - 77ms/step
# Epoch 3953/4000
#
# Epoch 3953: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 251311.5312 - val_loss: 7175.8047 - 504ms/epoch - 72ms/step
# Epoch 3954/4000
#
# Epoch 3954: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 251465.2344 - val_loss: 4808.8296 - 579ms/epoch - 83ms/step
# Epoch 3955/4000
#
# Epoch 3955: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 249269.0469 - val_loss: 4727.6748 - 1s/epoch - 149ms/step
# Epoch 3956/4000
#
# Epoch 3956: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 224526.4375 - val_loss: 4630.2993 - 1s/epoch - 147ms/step
# Epoch 3957/4000
#
# Epoch 3957: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 254693.2344 - val_loss: 5043.2119 - 987ms/epoch - 141ms/step
# Epoch 3958/4000
#
# Epoch 3958: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 238759.0938 - val_loss: 6351.3286 - 1s/epoch - 144ms/step
# Epoch 3959/4000
#
# Epoch 3959: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 230060.3281 - val_loss: 6787.5000 - 960ms/epoch - 137ms/step
# Epoch 3960/4000
#
# Epoch 3960: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 253212.4062 - val_loss: 5672.8125 - 948ms/epoch - 135ms/step
# Epoch 3961/4000
#
# Epoch 3961: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 240069.9062 - val_loss: 4652.3145 - 568ms/epoch - 81ms/step
# Epoch 3962/4000
#
# Epoch 3962: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 218334.7500 - val_loss: 7482.2251 - 526ms/epoch - 75ms/step
# Epoch 3963/4000
#
# Epoch 3963: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 240626.5156 - val_loss: 5529.2500 - 561ms/epoch - 80ms/step
# Epoch 3964/4000
#
# Epoch 3964: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 253062.6250 - val_loss: 4773.1758 - 570ms/epoch - 81ms/step
# Epoch 3965/4000
#
# Epoch 3965: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 267107.0312 - val_loss: 4626.9966 - 529ms/epoch - 76ms/step
# Epoch 3966/4000
#
# Epoch 3966: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 253023.5938 - val_loss: 4647.6992 - 559ms/epoch - 80ms/step
# Epoch 3967/4000
#
# Epoch 3967: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 230148.9219 - val_loss: 4618.8647 - 534ms/epoch - 76ms/step
# Epoch 3968/4000
#
# Epoch 3968: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 251259.7500 - val_loss: 5174.7725 - 510ms/epoch - 73ms/step
# Epoch 3969/4000
#
# Epoch 3969: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 232288.1406 - val_loss: 4643.8374 - 545ms/epoch - 78ms/step
# Epoch 3970/4000
#
# Epoch 3970: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 229392.1406 - val_loss: 5094.9336 - 506ms/epoch - 72ms/step
# Epoch 3971/4000
#
# Epoch 3971: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 281090.3438 - val_loss: 12274.6709 - 531ms/epoch - 76ms/step
# Epoch 3972/4000
#
# Epoch 3972: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 254367.4219 - val_loss: 5044.3315 - 532ms/epoch - 76ms/step
# Epoch 3973/4000
#
# Epoch 3973: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 243599.4219 - val_loss: 4656.2578 - 582ms/epoch - 83ms/step
# Epoch 3974/4000
#
# Epoch 3974: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 250105.5469 - val_loss: 4642.6543 - 508ms/epoch - 73ms/step
# Epoch 3975/4000
#
# Epoch 3975: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 262251.9375 - val_loss: 4756.0747 - 542ms/epoch - 77ms/step
# Epoch 3976/4000
#
# Epoch 3976: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 268521.9375 - val_loss: 4684.7588 - 559ms/epoch - 80ms/step
# Epoch 3977/4000
#
# Epoch 3977: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 249932.2969 - val_loss: 4620.8311 - 566ms/epoch - 81ms/step
# Epoch 3978/4000
#
# Epoch 3978: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 215124.3750 - val_loss: 5229.6826 - 515ms/epoch - 74ms/step
# Epoch 3979/4000
#
# Epoch 3979: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 236448.1094 - val_loss: 5202.0142 - 766ms/epoch - 109ms/step
# Epoch 3980/4000
#
# Epoch 3980: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 257619.3125 - val_loss: 4908.2847 - 1s/epoch - 151ms/step
# Epoch 3981/4000
#
# Epoch 3981: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 231584.5625 - val_loss: 5229.1816 - 1s/epoch - 147ms/step
# Epoch 3982/4000
#
# Epoch 3982: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 259387.4375 - val_loss: 7324.8057 - 1s/epoch - 152ms/step
# Epoch 3983/4000
#
# Epoch 3983: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 270609.3125 - val_loss: 5905.8667 - 1s/epoch - 148ms/step
# Epoch 3984/4000
#
# Epoch 3984: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 248326.7344 - val_loss: 4687.8477 - 1s/epoch - 147ms/step
# Epoch 3985/4000
#
# Epoch 3985: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 288924.8125 - val_loss: 4953.9336 - 546ms/epoch - 78ms/step
# Epoch 3986/4000
#
# Epoch 3986: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 252296.2656 - val_loss: 5448.6743 - 559ms/epoch - 80ms/step
# Epoch 3987/4000
#
# Epoch 3987: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 245590.2969 - val_loss: 8313.6348 - 522ms/epoch - 75ms/step
# Epoch 3988/4000
#
# Epoch 3988: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 241922.2656 - val_loss: 4649.7534 - 510ms/epoch - 73ms/step
# Epoch 3989/4000
#
# Epoch 3989: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 261037.7969 - val_loss: 4969.3911 - 574ms/epoch - 82ms/step
# Epoch 3990/4000
#
# Epoch 3990: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 244752.5156 - val_loss: 4965.5625 - 553ms/epoch - 79ms/step
# Epoch 3991/4000
#
# Epoch 3991: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 240025.1250 - val_loss: 4777.8169 - 513ms/epoch - 73ms/step
# Epoch 3992/4000
#
# Epoch 3992: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 241321.2344 - val_loss: 4975.6499 - 580ms/epoch - 83ms/step
# Epoch 3993/4000
#
# Epoch 3993: loss did not improve from 199819.53125
# 7/7 - 0s - loss: 248213.7031 - val_loss: 5374.1938 - 500ms/epoch - 71ms/step
# Epoch 3994/4000
#
# Epoch 3994: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 236572.8750 - val_loss: 4797.2861 - 553ms/epoch - 79ms/step
# Epoch 3995/4000
#
# Epoch 3995: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 252380.8906 - val_loss: 8262.3037 - 552ms/epoch - 79ms/step
# Epoch 3996/4000
#
# Epoch 3996: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 239602.4688 - val_loss: 5078.2290 - 546ms/epoch - 78ms/step
# Epoch 3997/4000
#
# Epoch 3997: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 273911.8125 - val_loss: 5158.0308 - 516ms/epoch - 74ms/step
# Epoch 3998/4000
#
# Epoch 3998: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 224788.9688 - val_loss: 8092.7041 - 532ms/epoch - 76ms/step
# Epoch 3999/4000
#
# Epoch 3999: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 256907.7812 - val_loss: 6109.0088 - 544ms/epoch - 78ms/step
# Epoch 4000/4000
#
# Epoch 4000: loss did not improve from 199819.53125
# 7/7 - 1s - loss: 246933.5312 - val_loss: 4840.6631 - 520ms/epoch - 74ms/step
# 16/16 [==============================] - 1s 11ms/step
# 3/3 [==============================] - 0s 11ms/step
# Training MSE: 2934.9983389125755
# Testing MSE: 20524.376146585542
# accuracy : 52
